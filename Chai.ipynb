# %% [markdown]
# <a href="https://colab.research.google.com/github/CHAI24-ai/simple_greeting.py/blob/main/Chai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# simple_greeting.py

def greet(name):
    """
    This function takes a name as input and returns a greeting message.
    """
    return f"Hello, {name}! Welcome to your first GitHub Python project."

if __name__ == "__main__":
    user_name = input("Enter your name: ")
    message = greet(user_name)
    print(message)
# Out:
# Enter your name: Chaithra HK
# Hello, Chaithra HK! Welcome to your first GitHub Python project.
